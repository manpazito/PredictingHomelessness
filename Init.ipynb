# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Requirement already satisfied: pandas in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 2)) (2.1.4)
# Requirement already satisfied: numpy in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 3)) (1.25.2)
# Requirement already satisfied: seaborn in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 4)) (0.13.2)
# Requirement already satisfied: matplotlib in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 5)) (3.6.3)
# Requirement already satisfied: geopandas in /toolkit-cache/0.2.0/python3.9/kernel-libs/lib/python3.9/site-packages (from -r ./requirements.txt (line 6)) (0.11.1)
# Requirement already satisfied: scikit-learn in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 7)) (1.1.3)
# Requirement already satisfied: pytz>=2020.1 in /root/venv/lib/python3.9/site-packages (from pandas->-r ./requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /root/venv/lib/python3.9/site-packages (from pandas->-r ./requirements.txt (line 2)) (2024.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /root/venv/lib/python3.9/site-packages (from pandas->-r ./requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in /root/venv/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 5)) (4.55.2)
# Requirement already satisfied: cycler>=0.10 in /root/venv/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /root/venv/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 5)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /root/venv/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 5)) (24.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /root/venv/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 5)) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /root/venv/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: pillow>=6.2.0 in /root/venv/lib/python3.9/site-packages (from matplotlib->-r ./requirements.txt (line 5)) (11.0.0)
# Requirement already satisfied: fiona>=1.8 in /toolkit-cache/0.2.0/python3.9/kernel-libs/lib/python3.9/site-packages (from geopandas->-r ./requirements.txt (line 6)) (1.9.6)
# Requirement already satisfied: shapely<2,>=1.7 in /toolkit-cache/0.2.0/python3.9/kernel-libs/lib/python3.9/site-packages (from geopandas->-r ./requirements.txt (line 6)) (1.8.5.post1)
# Requirement already satisfied: pyproj>=2.6.1.post1 in /toolkit-cache/0.2.0/python3.9/kernel-libs/lib/python3.9/site-packages (from geopandas->-r ./requirements.txt (line 6)) (3.5.0)
# Requirement already satisfied: joblib>=1.0.0 in /root/venv/lib/python3.9/site-packages (from scikit-learn->-r ./requirements.txt (line 7)) (1.4.2)
# Requirement already satisfied: scipy>=1.3.2 in /root/venv/lib/python3.9/site-packages (from scikit-learn->-r ./requirements.txt (line 7)) (1.9.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /root/venv/lib/python3.9/site-packages (from scikit-learn->-r ./requirements.txt (line 7)) (3.5.0)
# Requirement already satisfied: click~=8.0 in /root/venv/lib/python3.9/site-packages (from fiona>=1.8->geopandas->-r ./requirements.txt (line 6)) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /toolkit-cache/0.2.0/python3.9/kernel-libs/lib/python3.9/site-packages (from fiona>=1.8->geopandas->-r ./requirements.txt (line 6)) (1.1.1)
# Requirement already satisfied: certifi in /root/venv/lib/python3.9/site-packages (from fiona>=1.8->geopandas->-r ./requirements.txt (line 6)) (2024.8.30)
# Requirement already satisfied: attrs>=19.2.0 in /root/venv/lib/python3.9/site-packages (from fiona>=1.8->geopandas->-r ./requirements.txt (line 6)) (24.2.0)
# Requirement already satisfied: cligj>=0.5 in /toolkit-cache/0.2.0/python3.9/kernel-libs/lib/python3.9/site-packages (from fiona>=1.8->geopandas->-r ./requirements.txt (line 6)) (0.7.2)
# Requirement already satisfied: six in /root/venv/lib/python3.9/site-packages (from fiona>=1.8->geopandas->-r ./requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: importlib-metadata in /root/venv/lib/python3.9/site-packages (from fiona>=1.8->geopandas->-r ./requirements.txt (line 6)) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in /root/venv/lib/python3.9/site-packages (from importlib-metadata->fiona>=1.8->geopandas->-r ./requirements.txt (line 6)) (3.21.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=efed36f5-7279-494f-969b-eecafdcaaafd' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
